# %% [markdown]
# # PANDAS CASE STUDY
# WE WILL CHECK DATA FAO STAT

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
df = pd.read_csv(r"C:\Users\Asad\Desktop\Data_Assignment\FAOSTAT_data_1-12-2022.csv")

# %%
# Basis statistics or summary of data
df.describe()
# Out:
#        Area Code  Element Code  Item Code    Year Code         Year  \
# count      180.0    180.000000      180.0   180.000000   180.000000
# mean       231.0   5413.666667     1717.0  1990.500000  1990.500000
# std          0.0     81.146808        0.0    17.366409    17.366409
# min        231.0   5312.000000     1717.0  1961.000000  1961.000000
# 25%        231.0   5312.000000     1717.0  1975.750000  1975.750000
# 50%        231.0   5419.000000     1717.0  1990.500000  1990.500000
# 75%        231.0   5510.000000     1717.0  2005.250000  2005.250000
# max        231.0   5510.000000     1717.0  2020.000000  2020.000000
#
#               Value
# count  1.800000e+02
# mean   1.235340e+08
# std    1.427124e+08
# min    2.522300e+04
# 25%    6.438125e+04
# 50%    6.076251e+07
# 75%    2.376391e+08
# max    5.034661e+08

# %%
df.head()
# Out:
#   Domain Code                        Domain  Area Code  \
# 0         QCL  Crops and livestock products        231
# 1         QCL  Crops and livestock products        231
# 2         QCL  Crops and livestock products        231
# 3         QCL  Crops and livestock products        231
# 4         QCL  Crops and livestock products        231
#
#                        Area  Element Code         Element  Item Code  \
# 0  United States of America          5312  Area harvested       1717
# 1  United States of America          5419           Yield       1717
# 2  United States of America          5510      Production       1717
# 3  United States of America          5312  Area harvested       1717
# 4  United States of America          5419           Yield       1717
#
#              Item  Year Code  Year    Unit      Value Flag  \
# 0  Cereals, Total       1961  1961      ha   64869558    A
# 1  Cereals, Total       1961  1961   hg/ha      25223   Fc
# ...

# %%
# Install csv viewer , or excel viewer an we can check file by using csv viewer

# how can we do basic commands on this FAO Dataset
df.head(5)
# Out:
#   Domain Code                        Domain  Area Code  \
# 0         QCL  Crops and livestock products        231
# 1         QCL  Crops and livestock products        231
# 2         QCL  Crops and livestock products        231
# 3         QCL  Crops and livestock products        231
# 4         QCL  Crops and livestock products        231
#
#                        Area  Element Code         Element  Item Code  \
# 0  United States of America          5312  Area harvested       1717
# 1  United States of America          5419           Yield       1717
# 2  United States of America          5510      Production       1717
# 3  United States of America          5312  Area harvested       1717
# 4  United States of America          5419           Yield       1717
#
#              Item  Year Code  Year    Unit      Value Flag  \
# 0  Cereals, Total       1961  1961      ha   64869558    A
# 1  Cereals, Total       1961  1961   hg/ha      25223   Fc
# ...

# %%
new_df=df.drop(['Flag' , 'Flag Description' , 'Item' , ] , axis=1)
new_df.head(5)
# Out:
#   Domain Code                        Domain  Area Code  \
# 0         QCL  Crops and livestock products        231
# 1         QCL  Crops and livestock products        231
# 2         QCL  Crops and livestock products        231
# 3         QCL  Crops and livestock products        231
# 4         QCL  Crops and livestock products        231
#
#                        Area  Element Code         Element  Item Code  \
# 0  United States of America          5312  Area harvested       1717
# 1  United States of America          5419           Yield       1717
# 2  United States of America          5510      Production       1717
# 3  United States of America          5312  Area harvested       1717
# 4  United States of America          5419           Yield       1717
#
#    Year Code  Year    Unit      Value
# 0       1961  1961      ha   64869558
# 1       1961  1961   hg/ha      25223
# 2       1961  1961  tonnes  163619978
# 3       1962  1962      ha   60548008
# ...

# %%
# writing in the end of code has similiar meaning instead of saving in new name 
df.drop(['Flag' , 'Flag Description' , 'Item' , ] , axis=1).head()
# Out:
#   Domain Code                        Domain  Area Code  \
# 0         QCL  Crops and livestock products        231
# 1         QCL  Crops and livestock products        231
# 2         QCL  Crops and livestock products        231
# 3         QCL  Crops and livestock products        231
# 4         QCL  Crops and livestock products        231
#
#                        Area  Element Code         Element  Item Code  \
# 0  United States of America          5312  Area harvested       1717
# 1  United States of America          5419           Yield       1717
# 2  United States of America          5510      Production       1717
# 3  United States of America          5312  Area harvested       1717
# 4  United States of America          5419           Yield       1717
#
#    Year Code  Year    Unit      Value
# 0       1961  1961      ha   64869558
# 1       1961  1961   hg/ha      25223
# 2       1961  1961  tonnes  163619978
# 3       1962  1962      ha   60548008
# ...

# %%
df.mean()
# Out:
# Area Code       2.310000e+02
# Element Code    5.413667e+03
# Item Code       1.717000e+03
# Year Code       1.990500e+03
# Year            1.990500e+03
# Value           1.235340e+08
# dtype: float64

# %%
df.groupby(["Element", 'Unit']).mean()
# Out:
#                        Area Code  Element Code  Item Code  Year Code    Year  \
# Element        Unit
# Area harvested ha          231.0        5312.0     1717.0     1990.5  1990.5
# Production     tonnes      231.0        5510.0     1717.0     1990.5  1990.5
# Yield          hg/ha       231.0        5419.0     1717.0     1990.5  1990.5
#
#                               Value
# Element        Unit
# Area harvested ha      6.200303e+07
# Production     tonnes  3.085482e+08
# Yield          hg/ha   5.063017e+04

# %%
df.value_counts(["Element"])
# Out:
# Element
# Area harvested    60
# Production        60
# Yield             60
# dtype: int64

# %%
df.groupby(["Element", 'Unit']).mean()
# Out:
#                        Area Code  Element Code  Item Code  Year Code    Year  \
# Element        Unit
# Area harvested ha          231.0        5312.0     1717.0     1990.5  1990.5
# Production     tonnes      231.0        5510.0     1717.0     1990.5  1990.5
# Yield          hg/ha       231.0        5419.0     1717.0     1990.5  1990.5
#
#                               Value
# Element        Unit
# Area harvested ha      6.200303e+07
# Production     tonnes  3.085482e+08
# Yield          hg/ha   5.063017e+04

# %%
# use of bolen operator

df[df['Value'] >= 10000].groupby(["Element", 'Unit']).mean()
# Out:
#                        Area Code  Element Code  Item Code  Year Code    Year  \
# Element        Unit
# Area harvested ha          231.0        5312.0     1717.0     1990.5  1990.5
# Production     tonnes      231.0        5510.0     1717.0     1990.5  1990.5
# Yield          hg/ha       231.0        5419.0     1717.0     1990.5  1990.5
#
#                               Value
# Element        Unit
# Area harvested ha      6.200303e+07
# Production     tonnes  3.085482e+08
# Yield          hg/ha   5.063017e+04
